# %%
### Model Testing ###

# each dataset should be in its own folder with a sheet
# there should be a notebook for each training set to add results to the sheets and create confusion matrices

### Datasets
# DAR stratified test set (6 images per cam and label = 144 images)

# Planned:
# stratified hivis test set (unseen sites)
# master test set (unseen Hawaiian streams, cam deployments)

### Models
# GPT baseline
# individual training
# unseen images DAR training

# Planned:
# hivis GPT baseline
# hivis training baseline
# background subtraction
