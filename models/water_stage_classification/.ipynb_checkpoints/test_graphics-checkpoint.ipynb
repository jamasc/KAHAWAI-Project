# %%
# notbook to use test1.py and generate confusion matrices

import test1
import importlib
import pandas as pd
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

importlib.reload(test1)

#test_acc, test_loss, label_counts, label_correct, label_confidences = test1.main('config_DAR1000.yaml')
results = test1.main('config_DAR1000.yaml')
# Out:
# Test Loss: 1.1204, Test Acc: 0.7083
#
# Per-label results:
# Label   0: Total=   6, Correct=   5, Accuracy= 83.33%, Avg Confidence=0.8694
# Label   1: Total=   6, Correct=   4, Accuracy= 66.67%, Avg Confidence=0.9589
# Label   2: Total=   6, Correct=   3, Accuracy= 50.00%, Avg Confidence=0.8795
# Label   3: Total=   6, Correct=   5, Accuracy= 83.33%, Avg Confidence=0.9314

# %%
# this code creates a confusion matrix for the accurracy of predictions

# Replace with your actual column names
y_true = results["label"]
y_pred = results["predicted"]

# Compute confusion matrix
labels = [2, 3, 1, 4]
display_labels = ['dry bed', 'isolated pools', 'run present', 'freshet']
cm = confusion_matrix(y_true, y_pred, labels=labels)

print("Confusion Matrix:")
print(cm)

# Plot it
disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=display_labels
)
disp.plot(cmap="Blues")
plt.title("Confusion Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 10
#       8 labels = [2, 3, 1, 4]
#       9 display_labels = ['dry bed', 'isolated pools', 'run present', 'freshet']
# ---> 10 cm = confusion_matrix(y_true, y_pred, labels=labels)
#      12 print("Confusion Matrix:")
#      13 print(cm)
#
# File ~/.conda/envs/streamflow-env/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/.conda/envs/streamflow-env/lib/python3.13/site-packages/sklearn/metrics/_classification.py:549, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     546     sample_weight = _convert_to_numpy(sample_weight, xp)
#     548 if len(sample_weight) > 0:
# --> 549     y_type, y_true, y_pred, sample_weight = _check_targets(
#     550         y_true, y_pred, sample_weight
#     551     )
#     552 else:
#     553     # This is needed to handle the special case where y_true, y_pred and
#     554     # sample_weight are all empty.
#     555     # In this case we don't pass sample_weight to _check_targets that would
#     556     # check that sample_weight is not empty and we don't reuse the returned
#     557     # sample_weight
#     558     y_type, y_true, y_pred, _ = _check_targets(y_true, y_pred)
#
# File ~/.conda/envs/streamflow-env/lib/python3.13/site-packages/sklearn/metrics/_classification.py:138, in _check_targets(y_true, y_pred, sample_weight)
#     136 # No metrics support "multiclass-multioutput" format
#     137 if y_type not in ["binary", "multiclass", "multilabel-indicator"]:
# --> 138     raise ValueError("{0} is not supported".format(y_type))
#     140 if y_type in ["binary", "multiclass"]:
#     141     try:
#
# ValueError: unknown is not supported
