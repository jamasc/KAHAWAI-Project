# %%
# this code takes one input image path and 1+ input strings, calls CLIPSeg, and returns the amount of pixels per input string as dict

import os
import pandas as pd
from pathlib import Path
from transformers import CLIPSegProcessor, CLIPSegForImageSegmentation
from PIL import Image
import torch
from tqdm import tqdm

# input
texts = ["water"]
image_path = "D:/Stream Camera Project/2019_StreamCams/2019_Photos/Deployment 1 (1000, M1)/100MEDIA/DSCF0069.JPG"

# Model inference
image = Image.open(image_path).convert("RGB")
inputs = processor(text=texts, images=[image] * len(texts), padding=True, return_tensors="pt")
inputs = {k: v.to(device) for k, v in inputs.items()}
outputs = model(**inputs)
logits = outputs.logits
probs = torch.sigmoid(logits)
pixels = (probs > 0.5).int().sum().item()

print(pixels)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import pandas as pd
#       5 from pathlib import Path
# ----> 6 from transformers import CLIPSegProcessor, CLIPSegForImageSegmentation
#       7 from PIL import Image
#       8 import torch
#
# ModuleNotFoundError: No module named 'transformers'
