# %%
# TLS Timelapse Frame Extractor
# Converts all .tls files in a folder to .avi and extracts all frames to subfolders using ffmpeg

import os
import shutil
import subprocess
from pathlib import Path

# --- CONFIGURATION ---
input_folder = Path(r"D:/palolo_images")  # ← change this to your folder path
output_base = input_folder / "frames"
output_base.mkdir(exist_ok=True)

ffmpeg_path = r"C:\Users\marks\AppData\Local\Microsoft\WinGet\Packages\Gyan.FFmpeg_Microsoft.Winget.Source_8wekyb3d8bbwe\ffmpeg-8.0-full_build\bin\ffmpeg.exe"

print(f"📂 Input folder: {input_folder}")
print(f"📸 Output folder: {output_base}\n")

tls_files = sorted(input_folder.glob("*.tls"))
if not tls_files:
    print("⚠️ No .tls files found. Check your folder path.")
else:
    for tls_path in tls_files:
        base_name = tls_path.stem
        avi_path = tls_path.with_suffix(".avi")

        # Copy to .avi (keeps original .tls intact)
        if not avi_path.exists():
            shutil.copy2(tls_path, avi_path)
            print(f"📄 Copied {tls_path.name} → {avi_path.name}")
        else:
            print(f"➡️ {avi_path.name} already exists, skipping copy.")

        # Create subfolder for frames
        frame_folder = output_base / base_name
        frame_folder.mkdir(exist_ok=True)

        # ffmpeg command to extract all frames
        frame_pattern = str(frame_folder / "frame_%04d.jpg")
        cmd = [ffmpeg_path, "-i", str(avi_path), "-q:v", "2", frame_pattern]

        print(f"🎞️ Extracting frames from {avi_path.name} → {frame_folder.name}")
        subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.STDOUT)

    print("\n✅ All TLS files processed and frames extracted successfully!")
# Out:
# 📂 Input folder: D:\palolo_images
# 📸 Output folder: D:\palolo_images\frames
#
# ➡️ TIMEL0001.avi already exists, skipping copy.
# 🎞️ Extracting frames from TIMEL0001.avi → TIMEL0001
# 📄 Copied TIMEL0002.TLS → TIMEL0002.avi
# 🎞️ Extracting frames from TIMEL0002.avi → TIMEL0002
# 📄 Copied TIMEL0003.TLS → TIMEL0003.avi
# 🎞️ Extracting frames from TIMEL0003.avi → TIMEL0003
# 📄 Copied TIMEL0004.TLS → TIMEL0004.avi
# 🎞️ Extracting frames from TIMEL0004.avi → TIMEL0004
# 📄 Copied TIMEL0005.TLS → TIMEL0005.avi
# 🎞️ Extracting frames from TIMEL0005.avi → TIMEL0005
# 📄 Copied TIMEL0006.TLS → TIMEL0006.avi
# 🎞️ Extracting frames from TIMEL0006.avi → TIMEL0006
# 📄 Copied TIMEL0007.TLS → TIMEL0007.avi
# 🎞️ Extracting frames from TIMEL0007.avi → TIMEL0007
# 📄 Copied TIMEL0008.TLS → TIMEL0008.avi
# 🎞️ Extracting frames from TIMEL0008.avi → TIMEL0008
# 📄 Copied TIMEL0009.TLS → TIMEL0009.avi
# 🎞️ Extracting frames from TIMEL0009.avi → TIMEL0009
# 📄 Copied TIMEL0010.TLS → TIMEL0010.avi
# 🎞️ Extracting frames from TIMEL0010.avi → TIMEL0010
# 📄 Copied TIMEL0011.TLS → TIMEL0011.avi
# 🎞️ Extracting frames from TIMEL0011.avi → TIMEL0011
# 📄 Copied TIMEL0012.TLS → TIMEL0012.avi
# 🎞️ Extracting frames from TIMEL0012.avi → TIMEL0012
# 📄 Copied TIMEL0013.TLS → TIMEL0013.avi
# 🎞️ Extracting frames from TIMEL0013.avi → TIMEL0013
# 📄 Copied TIMEL0014.TLS → TIMEL0014.avi
# 🎞️ Extracting frames from TIMEL0014.avi → TIMEL0014
# 📄 Copied TIMEL0015.TLS → TIMEL0015.avi
# 🎞️ Extracting frames from TIMEL0015.avi → TIMEL0015
# 📄 Copied TIMEL0016.TLS → TIMEL0016.avi
# 🎞️ Extracting frames from TIMEL0016.avi → TIMEL0016
# 📄 Copied TIMEL0017.TLS → TIMEL0017.avi
# 🎞️ Extracting frames from TIMEL0017.avi → TIMEL0017
# 📄 Copied TIMEL0018.TLS → TIMEL0018.avi
# 🎞️ Extracting frames from TIMEL0018.avi → TIMEL0018
# 📄 Copied TIMEL0019.TLS → TIMEL0019.avi
# 🎞️ Extracting frames from TIMEL0019.avi → TIMEL0019
# 📄 Copied TIMEL0020.TLS → TIMEL0020.avi
# 🎞️ Extracting frames from TIMEL0020.avi → TIMEL0020
# 📄 Copied TIMEL0021.TLS → TIMEL0021.avi
# 🎞️ Extracting frames from TIMEL0021.avi → TIMEL0021
# 📄 Copied TIMEL0022.TLS → TIMEL0022.avi
# 🎞️ Extracting frames from TIMEL0022.avi → TIMEL0022
# 📄 Copied TIMEL0023.TLS → TIMEL0023.avi
# 🎞️ Extracting frames from TIMEL0023.avi → TIMEL0023
# 📄 Copied TIMEL0024.TLS → TIMEL0024.avi
# 🎞️ Extracting frames from TIMEL0024.avi → TIMEL0024
# 📄 Copied TIMEL0025.TLS → TIMEL0025.avi
# 🎞️ Extracting frames from TIMEL0025.avi → TIMEL0025
# 📄 Copied TIMEL0026.TLS → TIMEL0026.avi
# 🎞️ Extracting frames from TIMEL0026.avi → TIMEL0026
# 📄 Copied TIMEL0027.TLS → TIMEL0027.avi
# 🎞️ Extracting frames from TIMEL0027.avi → TIMEL0027
# 📄 Copied TIMEL0028.TLS → TIMEL0028.avi
# 🎞️ Extracting frames from TIMEL0028.avi → TIMEL0028
# 📄 Copied TIMEL0029.TLS → TIMEL0029.avi
# 🎞️ Extracting frames from TIMEL0029.avi → TIMEL0029
# 📄 Copied TIMEL0030.TLS → TIMEL0030.avi
# 🎞️ Extracting frames from TIMEL0030.avi → TIMEL0030
# 📄 Copied TIMEL0031.TLS → TIMEL0031.avi
# 🎞️ Extracting frames from TIMEL0031.avi → TIMEL0031
# 📄 Copied TIMEL0032.TLS → TIMEL0032.avi
# 🎞️ Extracting frames from TIMEL0032.avi → TIMEL0032
# 📄 Copied TIMEL0033.TLS → TIMEL0033.avi
# 🎞️ Extracting frames from TIMEL0033.avi → TIMEL0033
# 📄 Copied TIMEL0034.TLS → TIMEL0034.avi
# 🎞️ Extracting frames from TIMEL0034.avi → TIMEL0034
# 📄 Copied TIMEL0035.TLS → TIMEL0035.avi
# 🎞️ Extracting frames from TIMEL0035.avi → TIMEL0035
# 📄 Copied TIMEL0036.TLS → TIMEL0036.avi
# 🎞️ Extracting frames from TIMEL0036.avi → TIMEL0036
# 📄 Copied TIMEL0037.TLS → TIMEL0037.avi
# 🎞️ Extracting frames from TIMEL0037.avi → TIMEL0037
# 📄 Copied TIMEL0038.TLS → TIMEL0038.avi
# 🎞️ Extracting frames from TIMEL0038.avi → TIMEL0038
# 📄 Copied TIMEL0039.TLS → TIMEL0039.avi
# 🎞️ Extracting frames from TIMEL0039.avi → TIMEL0039
# 📄 Copied TIMEL0040.TLS → TIMEL0040.avi
# 🎞️ Extracting frames from TIMEL0040.avi → TIMEL0040
# 📄 Copied TIMEL0041.TLS → TIMEL0041.avi
# 🎞️ Extracting frames from TIMEL0041.avi → TIMEL0041
# 📄 Copied TIMEL0042.TLS → TIMEL0042.avi
# 🎞️ Extracting frames from TIMEL0042.avi → TIMEL0042
# 📄 Copied TIMEL0043.TLS → TIMEL0043.avi
# 🎞️ Extracting frames from TIMEL0043.avi → TIMEL0043
# 📄 Copied TIMEL0044.TLS → TIMEL0044.avi
# 🎞️ Extracting frames from TIMEL0044.avi → TIMEL0044
#
# ✅ All TLS files processed and frames extracted successfully!
